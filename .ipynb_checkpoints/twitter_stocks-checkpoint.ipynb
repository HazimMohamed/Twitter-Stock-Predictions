# %% [markdown]
# # Predicting Stock Movements from Twitter Data

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
from math import floor, ceil
from datetime import datetime, timedelta
import os
from sklearn.metrics import f1_score, confusion_matrix
import random
import tensorflow as tf

# %% [markdown]
# ## Preprocess the Twitter Data

# %%
twitter_data = pd.read_csv(os.getcwd() + '/data/Raw_tweets_09_30.csv', \
                           usecols=['created_at', 'tweet_text'], \
                           parse_dates=['created_at'])
twitter_data.rename({'tweet_text': 'content'}, inplace=True, axis='columns')
twitter_data
# Out:
#                  created_at                                            content
# 0       2019-06-24 17:58:26  Nouriel Roubini outlines the 2020 recession ri...
# 1       2019-06-24 17:58:33  @nyika_yedu The multi currency regime dealt wi...
# 2       2019-06-24 17:58:35  @jwoltmann @starboard_light People ARE paying ...
# 3       2019-06-24 17:58:46  The caution continues. "Small business owners ...
# 4       2019-06-24 17:59:00  Mapping The World's Financial Weak Spots - htt...
# ...                     ...                                                ...
# 1375259 2019-09-30 13:19:32  Band nerds can never know about me and the sto...
# 1375260 2019-09-30 13:19:33  @realDonaldTrump You manipulated a fake phone ...
# 1375261 2019-09-30 13:19:39  @Ian_Fraser USA SCARY SIGNS OF RECESSION - RET...
# 1375262 2019-09-30 13:19:41  @TexMinIndia @nsitharaman.dear medam / sirs, D...
# 1375263 2019-09-30 13:19:41                                                NaN
#
# [1375264 rows x 2 columns]

# %%
before_drop_len = len(twitter_data)
dropped_count = pd.DataFrame(columns=['Number dropped'])

# Drop rows with missing values
twitter_data.dropna(axis='index', inplace=True)
dropped_count.loc['NA'] = (before_drop_len-len(twitter_data),)
before_drop_len = len(twitter_data)

# Drop rows with hyperlinks
url_regex = r'http[s]?:\/\/t\.co\/[a-z,A-Z,0-9]+'
no_urls = twitter_data['content'].str.contains(url_regex)
indicies_to_drop = [df_index for df_index in twitter_data.index if no_urls[df_index]]
twitter_data.drop(index=indicies_to_drop, inplace=True)
dropped_count.loc['Hyperlinks'] = (before_drop_len-len(twitter_data),)

# Drop days not between June 25 2019 to September 27 2019 to match stock data
after_sep_27 = twitter_data['created_at'] > datetime(2020, 9, 27)
print(f'after sep 27: {after_sep_27.value_counts()}' )
before_june_5  = twitter_data['created_at'] < datetime(2019, 6, 25)
print(f'before june 5: {after_sep_27.value_counts()}' )
date_filter = ~(after_sep_27 | before_june_5)
print(f'date filter: {date_filter.value_counts()}' )
twitter_data = twitter_data[date_filter]

# Sum up total dropped
dropped_count.loc['Total'] = (dropped_count['Number dropped'].sum(),)
dropped_count
# Out:
# <ipython-input-201-81ce3c13d2d2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitter_data.dropna(axis='index', inplace=True)
# after sep 27: False    30939
# Name: created_at, dtype: int64
# before june 5: False    30939
# Name: created_at, dtype: int64
# date filter: True    30939
# Name: created_at, dtype: int64
# /Users/hazimmohamed/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#            Number dropped
# NA                      0
# Hyperlinks              0
# Total                   0

# %%
twitter_data
# Out:
#                  created_at                                            content
# 1       2019-06-24 17:58:33  @nyika_yedu The multi currency regime dealt wi...
# 2       2019-06-24 17:58:35  @jwoltmann @starboard_light People ARE paying ...
# 5       2019-06-24 17:59:03  Ann Sarnoff has a stock market background so W...
# 8       2019-06-24 17:59:33  @Ashe_Oro What do you think they will do with ...
# 10      2019-06-24 17:59:40                           @YoungOtutu in recession
# ...                     ...                                                ...
# 1375257 2019-09-30 13:19:09  Two main reasons driving a PMs Bulk market are...
# 1375259 2019-09-30 13:19:32  Band nerds can never know about me and the sto...
# 1375260 2019-09-30 13:19:33  @realDonaldTrump You manipulated a fake phone ...
# 1375261 2019-09-30 13:19:39  @Ian_Fraser USA SCARY SIGNS OF RECESSION - RET...
# 1375262 2019-09-30 13:19:41  @TexMinIndia @nsitharaman.dear medam / sirs, D...
#
# [681593 rows x 2 columns]

# %%
# See if filtering with expressive words is practical
expressive_words = ['I\'m', 'I am', 'feel', 'feels', 'bull', 'bear', 'makes me']
expressive_words_regex = re.compile('\s|'.join(expressive_words))
has_expressive = twitter_data['content'].str.contains(expressive_words_regex)
expressive_data_subset = twitter_data[has_expressive]
for c in expressive_data_subset['content'][:7]:
    print(c, '\n\n')
# Out:
# @TechQn @DiMartinoBooth @paranoidbull Japan has always wanted a low yen since they are an exporter nation. That is why they like NIRP even if they say they want inflation. If they want inflation they should stop raising taxes on their citizens.
#
#
# @VDalal1074 @DrAllahNizar_ @UN That's why India always bats for total restructuring of UN which won't be possible in nearest future I feel till as u said dollar dominates world economy
#
#
# @ScottNations So true and well said. I'm still getting my arms around the idea that more inflation generates more jobs. Haven't we already been down this road with NAIRU &amp; Phillips Curve. Why can't we let price discovery, even price for credit, work itself and avoid LT unintended consequences.
#
#
# @NorthmanTrader @HuXijin_GT That's what I'm hoping for - Trump thinks equities are giving him the green light to push China hard = finally market realising recession is in
#
#
# @BharathQuant @ByeByeMarket @LeederOfThePack It won't be millennial disinterest that holds back the market. It will be a big compression in multiples as inflation &amp; rising interest rates ultimately send market multiples back toward single digits. I'm not sure we'll see these levels again even in 20 yrs.
#
#
# @RandomGuySpain @starwart1 I'm so sorry y'all have a 14% unemployment rate... feel free to keep suppressing the Catalan freedom movement.
#
#
# @B_Paul06 So apparently he was booked in biz class from Paris to Charlotte but missed the flight &amp; the economy ticket from Paris to Dallas was his only option.
# I...don’t know. I fly a lot. I feel like a biz class seat from Paris to the US was open somewhere. Especially for $1500

# %%
expressive_dates = [d.date() for d in expressive_data_subset['created_at']]
sorted_dates = list(set([a.date() for a in twitter_data['created_at']]))
sorted_dates.sort()
num_expressive_per_day = [expressive_dates.count(date) for date in sorted_dates]
plt.bar(sorted_dates, num_expressive_per_day)
plt.plot(sorted_dates, [np.mean(num_expressive_per_day)] * len(sorted_dates))

# %%
twitter_data = expressive_data_subset
dates = expressive_dates
twitter_data
# Out:
#                  created_at                                            content
# 178     2019-06-24 18:21:00  @TechQn @DiMartinoBooth @paranoidbull Japan ha...
# 189     2019-06-24 18:21:55  @VDalal1074 @DrAllahNizar_ @UN That's why Indi...
# 272     2019-06-24 18:28:00  @ScottNations So true and well said. I'm still...
# 324     2019-06-24 18:30:45  @NorthmanTrader @HuXijin_GT That's what I'm ho...
# 348     2019-06-24 18:32:18  @BharathQuant @ByeByeMarket @LeederOfThePack I...
# ...                     ...                                                ...
# 1374853 2019-09-30 12:43:06  @sDehmej Hawk means obsessing about inflation....
# 1374915 2019-09-30 12:49:28  @tammyz3636 @TheofficialGump @KamalaHarris Abs...
# 1374999 2019-09-30 12:57:12  If it feels like recession smells like recessi...
# 1375138 2019-09-30 13:08:00  Though you may forget it in the next bull mark...
# 1375226 2019-09-30 13:15:57  So I had a dream a month ago and saw 7777 I to...
#
# [31758 rows x 2 columns]

# %%
# Publish as training data to use for human_rater.py
with open('./data/preprocessed_twitter.csv', 'w+') as preprocessed_data_file:
    twitter_data.to_csv(preprocessed_data_file, index_label=False)

# %% [markdown]
# ## Preprocessing the Stock Data

# %%
stock_data = pd.read_csv(os.getcwd() + '/data/prices_daily.csv', 
                         dtype={'DJIA CLOSE': np.float64, 'SP500 CLOSE': np.float64},
                         parse_dates=['Dates'],
                         index_col='Dates')

stock_data = stock_data.rename(columns={'DJIA CLOSE': 'DOW', 'SP500 CLOSE': 'SP'})
stock_data.sort_index()

def normalize(series):
    series = series- np.min(series)
    return series/np.max(series)

display(stock_data) 

plt.plot(stock_data.index, normalize(stock_data['DOW']))
plt.plot(stock_data.index, normalize(stock_data['SP']))
plt.show()
# Out:
#                  DOW       SP  VIX CLOSE
# Dates
# 2019-06-24  26727.54  2945.35      15.26
# 2019-06-25  26548.22  2917.38      16.28
# 2019-06-26  26536.82  2913.78      16.21
# 2019-06-27  26526.58  2924.92      15.82
# 2019-06-28  26599.96  2941.76      15.08
# ...              ...      ...        ...
# 2019-09-23  26949.99  2991.78      14.91
# 2019-09-24  26807.77  2966.60      17.05
# 2019-09-25  26970.71  2984.87      15.96
# 2019-09-26  26891.12  2977.62      16.07
# 2019-09-27  26820.25  2961.79      17.22
#
# [68 rows x 3 columns]

# %%
# Fill in missing days for stock data
dates_in_dataset = [dt.date() for dt in stock_data.index]
current_date = dates_in_dataset[0]
last_date =  dates_in_dataset[-1]
print('{} - {}'.format(current_date, last_date))
missing_dates = []
while current_date != last_date:
    if current_date not in dates_in_dataset:
        missing_dates.append(current_date)
    current_date += timedelta(days=1)

print('Missing dates: {}'.format([str(d) for d in missing_dates]))
plt.scatter(missing_dates, [0]*len(missing_dates))
plt.show()
# Out:
# 2019-06-24 - 2019-09-27
# Missing dates: ['2019-06-29', '2019-06-30', '2019-07-04', '2019-07-06', '2019-07-07', '2019-07-13', '2019-07-14', '2019-07-20', '2019-07-21', '2019-07-27', '2019-07-28', '2019-08-03', '2019-08-04', '2019-08-10', '2019-08-11', '2019-08-17', '2019-08-18', '2019-08-24', '2019-08-25', '2019-08-31', '2019-09-01', '2019-09-02', '2019-09-07', '2019-09-08', '2019-09-14', '2019-09-15', '2019-09-21', '2019-09-22']

# %%
# First build a series from the current series that includes all dates
def fill_in_missing(stock_time_series):
    stock_time_series =  stock_time_series[:]
    stock_time_series.sort_index(inplace=True)
    print('Sorted time series' + str(stock_time_series))
    print(f'First day: {stock_time_series.index[0]}')
    print(f'Last day: {stock_time_series.index[-1]}')
    num_days = (stock_time_series.index[-1] - stock_time_series.index[0]).days
    print(f'Num days: {num_days}')
    days = [stock_time_series.index[0] + timedelta(days=i) for i in range(num_days)]
    stock_time_series.index = days
    return stock_time_series
        
# TODO: fix this
# display(fill_in_mistock_data['DOW'])
display(fill_in_missing(stock_data['DOW']))
# Out:
# Sorted time seriesDates
# 2019-06-25    26548.22
# 2019-06-26    26536.82
# 2019-06-27    26526.58
# 2019-06-28    26599.96
# 2019-07-01    26717.43
#                 ...
# 2019-09-23    26949.99
# 2019-09-24    26807.77
# 2019-09-25    26970.71
# 2019-09-26    26891.12
# 2019-09-27    26820.25
# Name: DOW, Length: 67, dtype: float64
# First day: 2019-06-25 00:00:00
# Last day: 2019-09-27 00:00:00
# Num days: 94
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-019a1a1a4290> in <module>
#      14 # TODO: fix this
#      15 # display(fill_in_mistock_data['DOW'])
# ---> 16 display(fill_in_missing(stock_data['DOW']))
#
# <ipython-input-198-019a1a1a4290> in fill_in_missing(stock_time_series)
#       9     print(f'Num days: {num_days}')
#      10     days = [stock_time_series.index[0] + timedelta(days=i) for i in range(num_days)]
# ---> 11     stock_time_series.index = days
#      12     return stock_time_series
#      13
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_axis(self, axis, labels, fastpath)
#     399         object.__setattr__(self, "_index", labels)
#     400         if not fastpath:
# --> 401             self._data.set_axis(axis, labels)
#     402
#     403     def _set_subtyp(self, is_all_dates):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     175
#     176         if new_len != old_len:
# --> 177             raise ValueError(
#     178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 67 elements, new values have 94 elements

# %%
# Add delta column
def delta_for_col(col_series):
    return [col_series[date]-col_series[prev_date] for date, prev_date in zip(col_series.index,col_series.index[1:])]
    
stock_data['DOW_delta']  = [None] + delta_for_col(stock_data['DOW'])
stock_data['SP_delta'] = [None] + delta_for_col(stock_data['SP'])
display(stock_data)

# Drop the first row
stock_data.drop(index=stock_data.index[0], inplace=True)

plt.plot(stock_data.index, normalize(stock_data['DOW_delta']))
plt.plot(stock_data.index, normalize(stock_data['SP_delta']))
plt.show()
# Out:
#                  DOW       SP  VIX CLOSE  DOW_delta  SP_delta
# Dates
# 2019-06-24  26727.54  2945.35      15.26        NaN       NaN
# 2019-06-25  26548.22  2917.38      16.28     179.32     27.97
# 2019-06-26  26536.82  2913.78      16.21      11.40      3.60
# 2019-06-27  26526.58  2924.92      15.82      10.24    -11.14
# 2019-06-28  26599.96  2941.76      15.08     -73.38    -16.84
# ...              ...      ...        ...        ...       ...
# 2019-09-23  26949.99  2991.78      14.91     -14.92      0.29
# 2019-09-24  26807.77  2966.60      17.05     142.22     25.18
# 2019-09-25  26970.71  2984.87      15.96    -162.94    -18.27
# 2019-09-26  26891.12  2977.62      16.07      79.59      7.25
# 2019-09-27  26820.25  2961.79      17.22      70.87     15.83
#
# [68 rows x 5 columns]

# %%
# Add z score column
def z_score_col(col_series):
    std = np.std(col_series)
    mean = np.mean(col_series)
    return pd.Series([(x_i - mean)/std for x_i in col_series],index=col_series.index)

combined_sp_and_dow = (normalize(stock_data['SP']) + normalize(stock_data['DOW']))/2
stock_data['z_score'] = z_score_col(combined_sp_and_dow)
display(stock_data)

display(stock_data['z_score'].describe())
plt.hist(stock_data['z_score'], bins=30)
plt.show()
# Out:
#                  DOW       SP  VIX CLOSE  DOW_delta  SP_delta   z_score
# Dates
# 2019-06-25  26548.22  2917.38      16.28     179.32     27.97 -0.496005
# 2019-06-26  26536.82  2913.78      16.21      11.40      3.60 -0.543157
# 2019-06-27  26526.58  2924.92      15.82      10.24    -11.14 -0.442027
# 2019-06-28  26599.96  2941.76      15.08     -73.38    -16.84 -0.201729
# 2019-07-01  26717.43  2964.33      14.06    -117.47    -22.57  0.139145
# ...              ...      ...        ...        ...       ...       ...
# 2019-09-23  26949.99  2991.78      14.91     -14.92      0.29  0.641963
# 2019-09-24  26807.77  2966.60      17.05     142.22     25.18  0.250685
# 2019-09-25  26970.71  2984.87      15.96    -162.94    -18.27  0.593369
# 2019-09-26  26891.12  2977.62      16.07      79.59      7.25  0.442693
# 2019-09-27  26820.25  2961.79      17.22      70.87     15.83  0.214947
#
# [67 rows x 6 columns]
# count    6.700000e+01
# mean     1.396064e-16
# std      1.007547e+00
# min     -2.313976e+00
# 25%     -7.011653e-01
# 50%      3.424167e-01
# 75%      8.464832e-01
# max      1.269322e+00
# Name: z_score, dtype: float64

# %% [markdown]
# ## Build a Financial Sentiment Analyzer from VADER

# %%
financial_lexicon = pd.read_csv(os.getcwd() + '/data/stock_lex.csv', dtype={
    'Aff_Score': np.float64,
    'Neg_Score': np.float64
})
financial_lexicon['sentiment'] = (financial_lexicon['Aff_Score'] + financial_lexicon['Neg_Score'])/2
financial_lexicon
# Out:
#                 Item  POS  Aff_Score  Neg_Score  sentiment
# 0                'em   PR   0.379542   0.533419   0.456481
# 1                 'n   CC   1.413176   1.199917   1.306547
# 2          'n handle  NaN   2.839000   2.941000   2.890000
# 3               's a  NaN  -0.023077  -0.013615  -0.018346
# 4             's abc  NaN   2.261667   2.300000   2.280833
# ...              ...  ...        ...        ...        ...
# 20545           zoom   VB  -0.652273  -0.649174  -0.650723
# 20546  zortrades.com   NN   2.141000   2.163000   2.152000
# 20547            zte   NN   4.934000   5.084000   5.009000
# 20548           zuck   NN  -0.237857  -0.185172  -0.211515
# 20549     zuckerberg   NN  -0.309667  -0.236923  -0.273295
#
# [20550 rows x 5 columns]

# %%
# mutate the stock_lex.csv to match the sentiment file that vader expects
stock_lexicon = pd.read_csv('./data/stock_lex.csv').drop(columns='POS')
stock_lexicon
# Out:
#                 Item  Aff_Score  Neg_Score
# 0                'em   0.379542   0.533419
# 1                 'n   1.413176   1.199917
# 2          'n handle   2.839000   2.941000
# 3               's a  -0.023077  -0.013615
# 4             's abc   2.261667   2.300000
# ...              ...        ...        ...
# 20545           zoom  -0.652273  -0.649174
# 20546  zortrades.com   2.141000   2.163000
# 20547            zte   4.934000   5.084000
# 20548           zuck  -0.237857  -0.185172
# 20549     zuckerberg  -0.309667  -0.236923
#
# [20550 rows x 3 columns]

# %%
plt.scatter(stock_lexicon['Aff_Score'], stock_lexicon['Neg_Score'])
plt.show()

# %%
stock_lexicon['sentiment'] = (stock_lexicon['Aff_Score'] + stock_lexicon['Neg_Score'])/2
stock_lexicon.drop(columns=['Aff_Score', 'Neg_Score'], inplace=True, errors='ignore')
stock_lexicon.rename(columns={'Item': 'word'}, inplace=True)
stock_lexicon
# Out:
#                 word  sentiment
# 0                'em   0.456481
# 1                 'n   1.306547
# 2          'n handle   2.890000
# 3               's a  -0.018346
# 4             's abc   2.280833
# ...              ...        ...
# 20545           zoom  -0.650723
# 20546  zortrades.com   2.152000
# 20547            zte   5.009000
# 20548           zuck  -0.211515
# 20549     zuckerberg  -0.273295
#
# [20550 rows x 2 columns]

# %%
# Convert to a format vader can understand
stock_lexicon_str_list = []
for i in range(len(stock_lexicon)):
    row = stock_lexicon.iloc[i]
    stock_lexicon_str_list.append('{}\t{}'.format(row['word'], row['sentiment']))
stock_lexicon_str = '\n'.join(stock_lexicon_str_list)

# %%
# Hacky solution for adding a custom lexicon
sentiment_analyzer = SentimentIntensityAnalyzer()
sentiment_analyzer.lexicon_full_filepath = stock_lexicon_str
sentiment_analyzer.lex_dict = sentiment_analyzer.make_lex_dict()

# %% [markdown]
# ## Testing the Assigned Sentiments vs Ground Truth

# %%
human_rated_tweets = pd.read_csv('./data/human_rated_tweets.csv')
human_rated_tweets.head(15)
# Out:
#     Unnamed: 0           created_at  \
# 0          178  2019-06-24 18:21:00
# 1          189  2019-06-24 18:21:55
# 2          272  2019-06-24 18:28:00
# 3          324  2019-06-24 18:30:45
# 4          348  2019-06-24 18:32:18
# 5          371  2019-06-24 18:34:11
# 6          377  2019-06-24 18:34:44
# 7          420  2019-06-24 18:37:54
# 8          475  2019-06-24 18:42:07
# 9          514  2019-06-24 18:45:31
# 10         542  2019-06-24 18:47:34
# 11         560  2019-06-24 18:49:51
# 12         581  2019-06-24 18:52:13
# 13         678  2019-06-24 19:01:07
# 14         699  2019-06-24 19:02:40
#
#                                               content  true_sentiment
# 0   @TechQn @DiMartinoBooth @paranoidbull Japan ha...              -1
# 1   @VDalal1074 @DrAllahNizar_ @UN That's why Indi...               0
# 2   @ScottNations So true and well said. I'm still...              -1
# 3   @NorthmanTrader @HuXijin_GT That's what I'm ho...              -3
# 4   @BharathQuant @ByeByeMarket @LeederOfThePack I...              -3
# 5   @RandomGuySpain @starwart1 I'm so sorry y'all ...              -3
# 6   @B_Paul06 So apparently he was booked in biz c...               0
# 7   Small political tweet incoming. I can't help b...               2
# 8   @matthew_peirson Tax break? A one time check v...               0
# 9   @AttackingCB Yeah I think that is the main rea...               1
# 10  @Convolutedname Fair point but I'm not even su...               0
# 11  @NialElkim @never_a_fan @ReviveTribalism @Kalk...              -1
# 12  @dave_schwager @splootman @FOHMaster @MullerBa...              -3
# 13  @digimontamer456 They want to feel powerful by...              -1
# 14  @WeatherGeek68 @KwikWarren Basically what I sa...              -3

# %%
vader_ratings = []
for tweet in human_rated_tweets['content']:
    polarity = sentiment_analyzer.polarity_scores(tweet)
    vader_ratings.append(polarity['compound'])
human_rated_tweets['vader_sentiment'] = vader_ratings
human_rated_tweets.head(15)
# Out:
#     Unnamed: 0           created_at  \
# 0          178  2019-06-24 18:21:00
# 1          189  2019-06-24 18:21:55
# 2          272  2019-06-24 18:28:00
# 3          324  2019-06-24 18:30:45
# 4          348  2019-06-24 18:32:18
# 5          371  2019-06-24 18:34:11
# 6          377  2019-06-24 18:34:44
# 7          420  2019-06-24 18:37:54
# 8          475  2019-06-24 18:42:07
# 9          514  2019-06-24 18:45:31
# 10         542  2019-06-24 18:47:34
# 11         560  2019-06-24 18:49:51
# 12         581  2019-06-24 18:52:13
# 13         678  2019-06-24 19:01:07
# 14         699  2019-06-24 19:02:40
#
#                                               content  true_sentiment  \
# 0   @TechQn @DiMartinoBooth @paranoidbull Japan ha...              -1
# 1   @VDalal1074 @DrAllahNizar_ @UN That's why Indi...               0
# 2   @ScottNations So true and well said. I'm still...              -1
# 3   @NorthmanTrader @HuXijin_GT That's what I'm ho...              -3
# 4   @BharathQuant @ByeByeMarket @LeederOfThePack I...              -3
# 5   @RandomGuySpain @starwart1 I'm so sorry y'all ...              -3
# 6   @B_Paul06 So apparently he was booked in biz c...               0
# 7   Small political tweet incoming. I can't help b...               2
# 8   @matthew_peirson Tax break? A one time check v...               0
# 9   @AttackingCB Yeah I think that is the main rea...               1
# 10  @Convolutedname Fair point but I'm not even su...               0
# 11  @NialElkim @never_a_fan @ReviveTribalism @Kalk...              -1
# 12  @dave_schwager @splootman @FOHMaster @MullerBa...              -3
# 13  @digimontamer456 They want to feel powerful by...              -1
# 14  @WeatherGeek68 @KwikWarren Basically what I sa...              -3
#
#     vader_sentiment
# 0           -0.0516
# 1            0.0516
# 2            0.7056
# 3            0.2500
# 4            0.2589
# 5            0.5939
# 6            0.1154
# 7           -0.7999
# 8            0.7536
# 9           -0.9144
# 10          -0.5984
# 11          -0.3400
# 12           0.3818
# 13          -0.4215
# 14          -0.0516

# %%
vader_positives = human_rated_tweets['vader_sentiment'] > 0
true_positives = human_rated_tweets['true_sentiment'] > 0
random_positives = [random.randint(0,1) > 0 for i in range(len(human_rated_tweets))]
vader_f1 = f1_score(true_positives, vader_positives)
random_f1 = f1_score(true_positives, random_positives)
pd.DataFrame({'F1 Score': [vader_f1, random_f1]}, index=['Vader', 'Random Guessing'])
# Out:
#                  F1 Score
# Vader            0.434783
# Random Guessing  0.333333

# %%
confusion_mat = confusion_matrix(true_positives, vader_positives)
pd.DataFrame({'Predicted Positive': confusion_mat.T[1], 'Predicted Negative': confusion_mat.T[0]}, index=['True Negative', 'True Positive'])
# Out:
#                Predicted Positive  Predicted Negative
# True Negative                  24                  15
# True Positive                  10                   2

# %%
twitter_data['sentiment'] = [sentiment_analyzer.polarity_scores(word)['compound'] for word in twitter_data['content']]
twitter_data
# Out:
# <ipython-input-186-54c1c39d7670>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitter_data['sentiment'] = [sentiment_analyzer.polarity_scores(word)['compound'] for word in twitter_data['content']]
#                  created_at  \
# 178     2019-06-24 18:21:00
# 189     2019-06-24 18:21:55
# 272     2019-06-24 18:28:00
# 324     2019-06-24 18:30:45
# 348     2019-06-24 18:32:18
# ...                     ...
# 1374853 2019-09-30 12:43:06
# 1374915 2019-09-30 12:49:28
# 1374999 2019-09-30 12:57:12
# 1375138 2019-09-30 13:08:00
# 1375226 2019-09-30 13:15:57
#
#                                                    content  sentiment
# 178      @TechQn @DiMartinoBooth @paranoidbull Japan ha...    -0.0516
# 189      @VDalal1074 @DrAllahNizar_ @UN That's why Indi...     0.0516
# 272      @ScottNations So true and well said. I'm still...     0.7056
# 324      @NorthmanTrader @HuXijin_GT That's what I'm ho...     0.2500
# 348      @BharathQuant @ByeByeMarket @LeederOfThePack I...     0.2589
# ...                                                    ...        ...
# 1374853  @sDehmej Hawk means obsessing about inflation....     0.0008
# 1374915  @tammyz3636 @TheofficialGump @KamalaHarris Abs...     0.9248
# 1374999  If it feels like recession smells like recessi...    -0.5719
# 1375138  Though you may forget it in the next bull mark...    -0.1043
# 1375226  So I had a dream a month ago and saw 7777 I to...     0.6956
#
# [31758 rows x 3 columns]

# %%
days = twitter_data['created_at'].dt.date
days.drop_duplicates(inplace=True)
daily_sentiment = [np.mean(twitter_data[twitter_data['created_at'].dt.date == day]['sentiment']) for day in days]
plt.plot(days[:], normalize(daily_sentiment)*1.3)
plt.plot(stock_data.index, normalize(stock_data['DOW']))
plt.show()
# Out:
# /Users/hazimmohamed/opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py:1480: SettingWithCopyWarning: modifications to a property of a datetimelike object are not supported and are discarded. Change values on the original.
#   return self._update_inplace(result)

# %% [markdown]
# ## Formatting the Data as A Supervised Learning Problem

# %%
def format_supervised_learning(data, num_days_given=5):
    for i in range(len())

# %% [markdown]
# ## Training Models

# %%
training_sentiment = normalize(daily_sentiment)
training_stock = list(normalize(stock_data['DOW']))
print(len(stock_data))
print(len(training_sentiment))
plt.plot(training_stock)
plt.plot(training_sentiment)
plt.show()
# Out:
# 67
# 99

# %%
dense_neural_network = tf.keras.Sequential(
    tf.keras.layers.Flatten(input_shape=(6,2))
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=1)
)

dense_neural_network

# %%
def normalize(series):
    series = np.array(series)
    possible_range = max(series) - min(series)
    series = series - min(series)
    series = series / possible_range
    return series

def pad(series, length_after_padding):
    return np.array(list(series) + [series[-1]]*(length_after_padding - len(series)))

MOVING_AVERAGE_WINDOW_SIZE = 50
sentiment_moving_average = moving_average(data['sentiment'], 500)

prices = pd.read_csv('./data/prices_60m.csv')
prices = prices.sample(min(len(prices), len(data)))

print(len(prices))
print(len(sentiment_moving_average))

prices_moving_average = moving_average(prices['SP500 CLOSE'], 50)
  
plt.plot(pd.to_datetime(data['created_at']), pad(normalize(sentiment_moving_average), len(data)))
plt.plot(pd.to_datetime(prices['Dates']), pad(normalize(prices_moving_average), len(prices['Dates'])))
plt.show()
# Out:
# 480
# 7552

# %% [markdown]
# Analyze as supervised learning problem

# %% [markdown]
# Analyze as timeseries problem

# %% [markdown]
# ## Testing the Models

# %% [markdown]
# ## Biasing Existing Stock Models with Twitter Data
