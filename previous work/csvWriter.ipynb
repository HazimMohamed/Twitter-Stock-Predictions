# %%
# !pip install tweepy
import tweepy

consumer_key='MA2UZIPKf5acnH8XwTwNBFo9p'
consumer_secret='d5Opx5bR1wURwosBgTPB3JwqrcYQl5fgKDYa26va5vmlIV8Wui'
access_key='1219699677236473856-gOJApJQmDT1pJ2LckCHP9HnS9QX09f'
access_secret='zYE7yFxdji62VukkMruYszts4AW0d0RdCtLROWKtqhVYY'

#authorize twitter, initialize tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

with open('data.csv', 'w', encoding="utf-8") as file:
    for status in tweepy.Cursor(api.search, q='dogecoin -filter:retweets ', count=100).items(300):
        if status is not None:
            status.text = (status.text).replace(',', '')
            file.write(status.created_at.strftime("%m/%d/%Y") + ',' + status.user.name + ',' + status.text + '\n')

# %%
import pandas as pd

data = pd.read_csv('./data.csv')
data.columns = columns=['created_at', 'username', 'text']
data
# Out:
#                                             created_at          username  \
# 0                                           11/14/2020      Trading Edge
# 1    Piercing with swing low formed at EMA20 key le...               NaN
# 2    $BTC $ETH $VET #bitcoin #altcoin… https://t.co...               NaN
# 3                                           11/14/2020          Alt Cash
# 4                                           11/14/2020           Skipper
# ..                                                 ...               ...
# 351                                         11/14/2020    CEO of Nothing
# 352               I noticed t… https://t.co/jObLLwhNg2               NaN
# 353                                         11/14/2020  Vladimir Kiselev
# 354                                         11/14/2020             Hamad
# 355                                         11/14/2020       Carlos Cruz
#
#                                                   text
# ...
